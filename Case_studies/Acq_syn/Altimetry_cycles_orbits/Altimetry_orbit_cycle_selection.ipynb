# %% [markdown]
# <img src='https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/tools/frameworks/-/raw/main/img/Standard_banner.png' align='right' width='100%'/>

# %% [markdown]
# <a href="../../../Index.ipynb"><< Index</a>
# <br>

# %% [markdown]
# <font color="#138D75">**Copernicus Marine Training Service**</font> <br>
# **Copyright:** 2024 European Union <br>
# **License:** MIT <br>
# **Authors:** Ben Loveday (EUMETSAT/Innoflair UG), Hayley Evers-King (EUMETSAT)

# %% [markdown]
# <html>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/applications/ocean-case-studies"><img src="https://img.shields.io/badge/open-EUMETLAB-E67E22.svg"></a></div>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://user.eumetsat.int/data/themes/marine"><img src="https://img.shields.io/badge/open-USER PORTAL-154360.svg"></a></div>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://mybinder.org/v2/git/https%3A%2F%2Fgitlab.eumetsat.int%2Feumetlab%2Foceans%2Focean-training%2Fapplications%2Focean-case-studies/HEAD?labpath=Case_studies%2FAcq_syn%2FAltimetry_cycles_orbits%2FAltimetry_orbit_cycle_selection.ipynb"><img src="https://mybinder.org/badge_logo.svg"></a></div>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://jupyterhub.prod.wekeo2.eu/hub/user-redirect/lab/tree/public/wekeo4oceans/ocean-case-studies/Case_studies/Acq_syn/Altimetry_cycles_orbits/Altimetry_orbit_cycle_selection.ipynb"><img src="https://img.shields.io/badge/launch-WEKEO-1a4696.svg"></a></div>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://code.insula.destine.eu/hub/"><img src="https://img.shields.io/badge/launch-DestinE-f43fd3.svg"></a></div></div>
# </html>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h3>Ocean case studies</h3></div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>PREREQUISITES </b>
#
# This notebook has the following prerequisites:
# - **<a href="https://eoportal.eumetsat.int/" target="_blank">A EUMETSAT Earth Observation Portal account</a>** to download from the EUMETSAT Data Store
#
# There are no prerequisite notebooks for this module.<br>
#
# </div>
# <hr>

# %% [markdown]
# # Selecting Copernicus altimetry products by orbital parameter
#
# ### Data used
#
# | Dataset | EUMETSAT Data Store<br>collection ID | EUMETSAT collection<br>description | WEkEO dataset ID | WEkEO description |
# |:--------------------:|:-----------------------:|:-------------:|:-----------------:|:-----------------:|
# | SRAL Level 2 Altimetry Global - Sentinel-3 | EO:EUM:DAT:0415 | <a href="https://user.eumetsat.int/catalogue/EO:EUM:DAT:SENTINEL-3:SR_2_WAT___NTC" target="_blank">Description</a> | EO:EUM:DAT:SENTINEL-3:SR_2_WAT___ | <a href="https://www.wekeo.eu/data?view=dataset&dataset=EO%3AEUM%3ADAT%3ASENTINEL-3%3ASR_2_WAT___" target="_blank">Description</a> |
# | Poseidon-4 Altimetry Level 2 High Resolution - Sentinel-6 | EO:EUM:DAT:0855 | <a href="https://user.eumetsat.int/catalogue/EO:EUM:DAT:0855" target="_blank">Description</a> | EO:EUM:DAT:0855 | <a href="https://www.wekeo.eu/data?view=dataset&dataset=EO%3AEUM%3ADAT%3A0855" target="_blank">Description</a>
#
# ### Learning outcomes
#
# At the end of this notebook you will know how to;
# * Access EUMETSAT Copernicus marine products from the EUMETSAT Data Store
# * Construct search queries to select altimetry products by orbital parameter
# * Download the selected products
#
# ### Outline
#
# <center><img src="https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/applications/ocean-case-studies/-/raw/main/img/Altimetry_orbits.png"/><br><b>Figure 1: Ground tracks for Sentinel-3 SRAL (left) and Sentinel-6 Poseidon-4 (right)</b></img></center><br>
#
# We often want to search for specific Earth observation products by time and or region of interest, but when we are considering altimetry products it is often more useful to identify a given cycle, or relative orbit. By considering sea surface height anomaliesover a single cycle we can add a single point to our global sea-level rise curve, while extracting data over a relative orbit can give us a time series over a single point or track, which is useful for identifying extremes.<br><br>
#
# <center><img src="https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/applications/ocean-case-studies/-/raw/main/img/Altimetry_naming.png" width="50%"/><br><b>Figure 2: File naming conventions for Sentinel-3 SRAL (top) and Sentinel-6 Poseidon-4 (bottom)</b></img></center><br>
#
# Much of the information we need is actually stored in the file names for Sentinel-3 and Sentinel-6 products, as shown above. You can find more information on the naming system for the products in the <a href="https://user.eumetsat.int/resources/user-guides/sentinel-safe-format-guide" target="_black">Sentinel-3</a> and <a href="https://www-cdn.eumetsat.int/files/2021-05/Jason-CS_Sentinel-6%20Generic%20File%20Naming%20Convention%20%28GFNC%29.pdf" target="_blank">Sentinel-6</a> product naming guides. However, the EUMETSAT Data Store encodes provides direct access to this information via product metadata, giving us an enhanced ability to search for and download the tracks we want.
#
# In this notebook we will show how to access the EUMETSAT Data Store, perform searches by cycle and relative orbit parameters and download the relevant products.
#
# <div class="alert alert-info" role="alert">
#
# ## <a id='TOCTOP'></a>Contents
#
# </div>
#
#  1. [Step 1: Setting up our analysis](#section1)
#  1. [Step 2: Authenticating the EUMETSAT Data Store](#section2)
#  1. [Step 3: Altimetry search options](#section3)
#  1. [Step 4: Searching for our specified products by cycle](#section4)
#  1. [Step 5: Plotting a single cycle](#section5)
#  1. [Step 6: Searching for our specified products by relative orbit](#section6)
#  1. [Step 7: Plotting a single relative orbit](#section7)
#  1. [Step 8: Conclusions](#section8)
#  1. [Step 9: Challenge (Optional)](#section9)
#
# <hr>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section1'></a>1. Setting up our analysis
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# We begin by importing all of the libraries that we need to run this notebook. If you have built your python using the environment file provided in this repository, then you should have everything you need. For more information on building environment, please see the repository **<a href="../../../README.md" target="_blank">README</a>**.

# %%
import cartopy                            # a package that helps with mapping and projection management
import datetime                           # a library that allows us to work with dates and times
import eumdac                             # a tool that helps us download via the eumetsat/data-store
import getpass                            # a library to help us enter passwords
import glob                               # a library that aids in searching for files
import matplotlib.pyplot as plt           # a library that support plotting
import numpy as np                        # a library that lets us work with arrays; we import this with a new name "np"
import os                                 # a library that allows us access to basic operating system commands
from pathlib import Path                  # a library to help us to construct system paths
import shutil                             # a library that allows us access to basic operating system commands like copy
import warnings                           # a library that helps us handle warnings
import xml.etree.ElementTree as ET        # a library that helps us parse XML files

# turn off any script warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We will make a few plots during this notebook, so lets quickly set our default fontsize for the whole notebook.

# %%
# set the default plot font size
plt.rcParams.update({'font.size': 18})

# %% [markdown]
# We are going to be running two experiments, one focussed on product cycles and one on product relative orbits. Lets create two directories `product_cycle` and `prodyct_relorbit` to store the data we need for both.

# %%
# Create a download directory for our altimetry products
download_dir_cycle = os.path.join(os.getcwd(), "products_cycle")
download_dir_relorbit = os.path.join(os.getcwd(), "products_relorbit")
os.makedirs(download_dir_cycle, exist_ok=True)
os.makedirs(download_dir_relorbit, exist_ok=True)

# %% [markdown]
# In the first instance of running this script, we want to download data, but in subsequent runs we may want to use what we have. The `download_data` switch below will tell us to download data (when `True`) or not (when `False`).

# %%
download_data = True

# %% [markdown]
# Next, we will define the parameters of our searches. Every "collection" (the term we use for a specific data type) is stored in the EUMETSAT Data Store by a specified collection ID. In our case, we want to identify the IDs for the data specified at the top of this notebook, the level-2 operational altimetry products from Sentinel-3 SRAL and Sentinel-6 Poseidon-4 (high resolution). We set these below.

# %%
S3_collectionID = "EO:EUM:DAT:0415"
S6_collectionID = "EO:EUM:DAT:0855"

# %% [markdown]
# Next we will set the "timeliness" if the data, which can be NR for near real-time, ST for short-time critical or NT for non time-critical. Different products are available at different timeliness, with the products that are more quickly available (e.g. NR) typically of slightly lower quality. We will look for NT products in both cases.

# %%
timeliness = "NT"

# %% [markdown]
# Now let us choose our orbital parameters for each experiment, selecting the cycle (`_cycle`), and relative orbit (`_relorbit`) in each case. Note that for the Sentinel-3 search, we are selecting only data from Sentinel-3B (`S3_satellite`) as the cycle numbers differ between the two satellites. NT altimetry products are distributed as half orbits, which means there are two in each relative orbit. By selecting the orbit direction (`_orbitdir`) we can select only the descending and ascending branch.

# %%
# S3 parameters
S3_satellite = "Sentinel-3B"
S3_cycle = 80
S3_relorbit = 308
S3_orbitdir = "DESCENDING"

# S6 parameters
S6_cycle = 118
S6_relorbit = 11
S6_orbitdir = "DESCENDING"

# %% [markdown]
# Finally, rather than download entire products, we will download just a single key components from each. In this case, we can construct the tracks from just the small xfdumenifest.xml file that describes the coverage of each track, so we'll get that to save disk space and download time.
#
# *Note: you can adapt the below to single out any combination of components to download*

# %%
components = ["xfdumanifest.xml"]

# %% [markdown]
# OK! Now we are ready to begin gathering our data for analysis, beginning by authenticating our access to the EUMETSAT Data Store.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section2'></a>2. Authenticating the EUMETSAT Data Store
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Accessing the EUMETSAT Data Store
#
# To access Copernicus marine data from the <a href="https://data.eumetsat.int " target="_blank">EUMETSAT Data Store</a>, we will use the EUMETSAT Data Access Client (`eumdac`) python package. If you are working with the recommended Anaconda Python distribution and used the environment file included in this repository (environment.yml) to build this python environment (as detailed in the README), you will already have installed this. If not, you can install eumdac using;
#
# `conda install -c eumetsat eumdac`
#
# You can also find the source code on the <a href="https://gitlab.eumetsat.int/eumetlab/data-services/eumdac " target="_blank">EUMETSAT GitLab</a>. Please visit the EUMETSAT user portal for more information on the <a href="https://user.eumetsat.int/data-access/data-store " target="_blank">EUMETSAT Data Store</a> and <a href="https://user.eumetsat.int/resources/user-guides/eumetsat-data-access-client-eumdac-guide " target="_blank">eumdac</a>.
#
# To download data from the EUMETSDAT Data Store via API, you need to provide credentials. To obtain these you should first register at for an <a href="https://eoportal.eumetsat.int/" target="_blank">EUMETSAT Earth Observation Portal account</a>. Once you have an account, you can retrieve your `<your_consumer_key>` and `<your_consumer_secret>` from the <a href="https://api.eumetsat.int/api-key/ " target="_blank">"EUMETSAT Data Store API"</a> page (*Note: you must click the "Show hidden fields" button at the bottom of the page to see the relevant fields*). If you do not already have a local credentials file, you will be prompted to enter your credentials when you run the cell below. This will create the required local credentials file, so that you only need to run this once.
#
# *Note: your key and secret are permanent, so you should take care to never share them*
#
# </div>

# %%
# load credentials
eumdac_credentials_file = Path(Path.home() / '.eumdac' / 'credentials')

if os.path.exists(eumdac_credentials_file):
    consumer_key, consumer_secret = Path(eumdac_credentials_file).read_text().split(',')
else:
    # creating authentication file
    consumer_key = input('Enter your consumer key: ')
    consumer_secret = getpass.getpass('Enter your consumer secret: ')
    try:
        os.makedirs(os.path.dirname(eumdac_credentials_file), exist_ok=True)
        with open(eumdac_credentials_file, "w") as f:
            f.write(f'{consumer_key},{consumer_secret}')
    except:
        pass
        
token = eumdac.AccessToken((consumer_key, consumer_secret))
print(f"This token '{token}' expires {token.expiration}")
# Out:
# This token 'b520244a-2d68-31fa-919e-db59c67ca741' expires 2024-05-13 10:07:19.906780

# %% [markdown]
# Now we have a token, we can create an instance of the EUMETSAT Data Store.

# %%
datastore = eumdac.DataStore(token)

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section3'></a>3. Altimetry search options
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# No we have out `datastore` object, we can test some of our searches. Lets start by retrieving our collections using the `get_collection` method.

# %%
# Use collection ID
S3_collection = datastore.get_collection(S3_collectionID)
S6_collection = datastore.get_collection(S6_collectionID)

# %% [markdown]
# When we have a collection, we can test to see what search options by calling its `search_options` method. For example;

# %%
S3_collection.search_options # if you run S6.collections, you will find that it is the same
# Out:
# {'bbox': {'title': 'Inventory which has a spatial extent overlapping this bounding box',
#   'options': []},
#  'geo': {'title': 'Inventory which has a spatial extent overlapping this Well Known Text geometry',
#   'options': []},
#  'title': {'title': 'Can be used to define a wildcard search on the product title (product identifier), use set notation as OR and space as AND operator between multiple search terms',
#   'options': [None]},
#  'sat': {'title': 'Mission / Satellite',
#   'options': ['Sentinel-3A', 'Sentinel-3B']},
#  'type': {'title': 'Product Type', 'options': ['SR_2_WAT___']},
#  'dtstart': {'title': 'Temporal Start', 'options': []},
#  'dtend': {'title': 'Temporal End', 'options': []},
#  'publication': {'title': 'publication date', 'options': []},
#  'zone': {'title': 'Equi7grid main continental zone',
#   'options': ['AN', 'NA', 'AS', 'OC', 'EU', 'SA', 'AF']},
#  't6': {'title': 'Equi7grid 600km tile', 'options': []},
#  'timeliness': {'title': 'Timeliness', 'options': ['NT', 'NR', 'ST']},
#  'orbit': {'title': 'Orbit Number, must be a positive integer', 'options': []},
#  'relorbit': {'title': 'Relative Orbit Number, must be a positive integer',
#   'options': []},
#  'orbitdir': {'title': 'Orbit Direction',
#   'options': ['ASCENDING', 'DESCENDING']},
#  'cycle': {'title': 'Cycle Number, must be a positive integer', 'options': []},
#  'sort': {'title': 'SRU sort keys, see OpenSearch Extension for EO for details',
#   'options': ['publicationDate', 'start,time']},
#  'set': {'title': 'element set to return for each hit, default is full',
#   'options': ['full', 'brief']}}

# %% [markdown]
# You will see that `cycle`, `relorbit` and `orbitdir` are all options, alongside other spatial and temporal search parameters.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section4'></a>4. Searching for our specified products by cycle
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# Now we know our search options we can use them to identify our products of interest. For experiment one, lets prune by cycle. We can construct our search parameter like so;

# %%
S3_products = S3_collection.search(cycle=S3_cycle, sat=S3_satellite, timeliness=timeliness)

# %% [markdown]
# Lets iterate through each product to see what we have. We'll also calculate the time of the initial and final products in the search, so we can check our cycle length.
#
# *Note: To reduce the length of this list, we'll only print out every 25th product.*

# %%
for product, index in zip(S3_products, range(len(S3_products))):
    if index == 0:
        # this calculates and prints the initial date
        init_datetime = datetime.datetime.strptime(str(product).split("_")[8], "%Y%m%dT%H%M%S")
        print(f'---{init_datetime}---')
    if index == len(S3_products) - 1:
        # this calculates and prints the final date
        final_datetime = datetime.datetime.strptime(str(product).split("_")[7], "%Y%m%dT%H%M%S")
        print(f'---{final_datetime} ({init_datetime - final_datetime}) ago ---')
    if np.mod(index, 25) == 0:
        print(f"{str(index + 1).zfill(3)}/{str(len(S3_products)).zfill(3)}: {product}")
# Out:
# ---2023-06-20 22:25:04---
# 001/773: S3B_SR_2_WAT____20230620T213944_20230620T222504_20230716T154946_2720_080_385______MAR_O_NT_005.SEN3
# 026/773: S3B_SR_2_WAT____20230620T003215_20230620T011638_20230715T190158_2663_080_373______MAR_O_NT_005.SEN3
# 051/773: S3B_SR_2_WAT____20230619T033210_20230619T042023_20230714T213330_2893_080_360______MAR_O_NT_005.SEN3
# 076/773: S3B_SR_2_WAT____20230618T062734_20230618T071255_20230714T002235_2721_080_348______MAR_O_NT_005.SEN3
# 101/773: S3B_SR_2_WAT____20230617T092839_20230617T101543_20230713T035548_2823_080_335______MAR_O_NT_005.SEN3
# 126/773: S3B_SR_2_WAT____20230616T131535_20230616T140352_20230712T072333_2896_080_323______MAR_O_NT_005.SEN3
# 151/773: S3B_SR_2_WAT____20230615T161103_20230615T165815_20230711T104227_2832_080_311______MAR_O_NT_005.SEN3
# 176/773: S3B_SR_2_WAT____20230614T191431_20230614T195908_20230710T132341_2677_080_298______MAR_O_NT_005.SEN3
# 201/773: S3B_SR_2_WAT____20230613T220622_20230613T225102_20230709T165124_2680_080_286______MAR_O_NT_005.SEN3
# 226/773: S3B_SR_2_WAT____20230613T015431_20230613T023858_20230708T200016_2667_080_274______MAR_O_NT_005.SEN3
# 251/773: S3B_SR_2_WAT____20230612T045610_20230612T054239_20230707T230926_2789_080_261______MAR_O_NT_005.SEN3
# 276/773: S3B_SR_2_WAT____20230611T074950_20230611T083523_20230707T015037_2733_080_249______MAR_O_NT_005.SEN3
# 301/773: S3B_SR_2_WAT____20230610T105012_20230610T113758_20230706T052519_2866_080_236______MAR_O_NT_005.SEN3
# 326/773: S3B_SR_2_WAT____20230609T134509_20230609T143213_20230705T075446_2824_080_224______MAR_O_NT_005.SEN3
# 351/773: S3B_SR_2_WAT____20230608T164913_20230608T173317_20230704T110151_2644_080_211______MAR_O_NT_005.SEN3
# 376/773: S3B_SR_2_WAT____20230607T194030_20230607T202815_20230703T140938_2865_080_199______MAR_O_NT_005.SEN3
# 401/773: S3B_SR_2_WAT____20230606T224315_20230606T232836_20230702T170759_2721_080_186______MAR_O_NT_005.SEN3
# 426/773: S3B_SR_2_WAT____20230606T013547_20230606T022010_20230701T201827_2663_080_174______MAR_O_NT_005.SEN3
# 451/773: S3B_SR_2_WAT____20230605T043810_20230605T052356_20230630T230730_2745_080_161______MAR_O_NT_005.SEN3
# 476/773: S3B_SR_2_WAT____20230604T073107_20230604T081632_20230630T014321_2725_080_149______MAR_O_NT_005.SEN3
# 501/773: S3B_SR_2_WAT____20230603T103142_20230603T111915_20230629T044810_2853_080_136______MAR_O_NT_005.SEN3
# 526/773: S3B_SR_2_WAT____20230602T132627_20230602T141243_20230628T072016_2776_080_124______MAR_O_NT_005.SEN3
# 551/773: S3B_SR_2_WAT____20230601T163028_20230601T171435_20230627T102920_2647_080_111______MAR_O_NT_005.SEN3
# 576/773: S3B_SR_2_WAT____20230531T192147_20230531T200949_20230626T133503_2881_080_099______MAR_O_NT_005.SEN3
# 601/773: S3B_SR_2_WAT____20230530T222431_20230530T230955_20230625T162724_2724_080_086______MAR_O_NT_005.SEN3
# 626/773: S3B_SR_2_WAT____20230530T011706_20230530T020114_20230624T193826_2648_080_074______MAR_O_NT_005.SEN3
# 651/773: S3B_SR_2_WAT____20230529T041727_20230529T050514_20230623T222409_2867_080_061______MAR_O_NT_005.SEN3
# 676/773: S3B_SR_2_WAT____20230528T071225_20230528T075756_20230623T005931_2731_080_049______MAR_O_NT_005.SEN3
# 701/773: S3B_SR_2_WAT____20230527T101304_20230527T110034_20230622T045053_2849_080_036______MAR_O_NT_005.SEN3
# 726/773: S3B_SR_2_WAT____20230526T130745_20230526T135407_20230621T073402_2782_080_024______MAR_O_NT_005.SEN3
# 751/773: S3B_SR_2_WAT____20230525T165554_20230525T174419_20230620T105134_2905_080_012______MAR_O_NT_005.SEN3
# ---2023-05-24 22:25:03 (27 days, 0:00:01) ago ---

# %% [markdown]
# We can see that we have 773 products in this cycle, which is 27 days in length, as expected for Sentinel-3 which has a 27-day revisit on the exact orbital track.
#
# Lets now check for Sentinel-6 in a near-identical way to the above (we change how we extract the file time a little!).

# %%
S6_products = S6_collection.search(cycle=S6_cycle, timeliness=timeliness)
for product, index in zip(S6_products, range(len(S6_products))):
    if index == 0:
        init_datetime = datetime.datetime.strptime(str(product).split("_")[11], "%Y%m%dT%H%M%S")
        print(f'---{init_datetime}---')
    if index == len(S6_products) - 1:
        final_datetime = datetime.datetime.strptime(str(product).split("_")[10], "%Y%m%dT%H%M%S")
        print(f'---{final_datetime} ({init_datetime - final_datetime}) ago ---')
    if np.mod(index, 25) == 0:
        print(f"{str(index + 1).zfill(3)}/{str(len(S6_products)).zfill(3)}: {product}")
# Out:
# ---2024-01-31 17:17:22---
# 001/254: S6A_P4_2__HR______20240131T162109_20240131T171722_20240222T141709_3373_118_254_127_EUM__OPE_NT_F08.SEN6
# 026/254: S6A_P4_2__HR______20240130T165547_20240130T175200_20240222T070635_3373_118_229_114_EUM__OPE_NT_F08.SEN6
# 051/254: S6A_P4_2__HR______20240129T173025_20240129T182638_20240222T002105_3373_118_204_102_EUM__OPE_NT_F08.SEN6
# 076/254: S6A_P4_2__HR______20240128T180503_20240128T190116_20240221T171701_3373_118_179_089_EUM__OPE_NT_F08.SEN6
# 101/254: S6A_P4_2__HR______20240127T183941_20240127T193554_20240221T100727_3373_118_154_077_EUM__OPE_NT_F08.SEN6
# 126/254: S6A_P4_2__HR______20240126T191419_20240126T201032_20240221T031504_3373_118_129_064_EUM__OPE_NT_F08.SEN6
# 151/254: S6A_P4_2__HR______20240125T194857_20240125T204510_20240220T202150_3373_118_104_052_EUM__OPE_NT_F08.SEN6
# 176/254: S6A_P4_2__HR______20240124T202335_20240124T211948_20240220T130344_3373_118_079_039_EUM__OPE_NT_F08.SEN6
# 201/254: S6A_P4_2__HR______20240123T205813_20240123T215426_20240220T055713_3373_118_054_027_EUM__OPE_NT_F08.SEN6
# 226/254: S6A_P4_2__HR______20240122T213251_20240122T222904_20240219T231358_3373_118_029_014_EUM__OPE_NT_F08.SEN6
# 251/254: S6A_P4_2__HR______20240121T220729_20240121T230342_20240211T101939_3373_118_004_002_EUM__OPE_NT_F08.SEN6
# ---2024-01-21 19:18:50 (9 days, 21:58:32) ago ---

# %% [markdown]
# A single cycle for Sentinel-6 takes ~10 days, and, in this case, contains 254 products. Lets download them, remembering that we are only fetching the specified manifest file component. The cell below will perform this task, making a new directory for each product.

# %%
if download_data:
    downloaded_components = []
    
    for product, count in zip(S6_products, range(len(S6_products))):
    
        product_download_directory = os.path.join(download_dir_cycle, str(product))
        os.makedirs(product_download_directory, exist_ok=True)
    
        # download the required product components
        for entry in product.entries:
            res = [ele for ele in components if(ele == os.path.basename(entry))]
            if res:
                with product.open(entry=entry) as fsrc, open(os.path.join(product_download_directory, fsrc.name),
                                                            mode='wb') as fdst:
                    downloaded_components.append(os.path.join(product_download_directory, fsrc.name))
                    print(f'Downloading ({count+1}/{len(S6_products)}) {product}: {fsrc.name}.')
                    shutil.copyfileobj(fsrc, fdst)
else:
    downloaded_components = sorted(glob.glob(os.path.join(download_dir_cycle, "*", components[0])))
# Out:
# Downloading (1/254) S6A_P4_2__HR______20240131T162109_20240131T171722_20240222T141709_3373_118_254_127_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (2/254) S6A_P4_2__HR______20240131T152456_20240131T162109_20240222T135347_3373_118_253_126_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (3/254) S6A_P4_2__HR______20240131T142843_20240131T152456_20240222T134218_3373_118_252_126_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (4/254) S6A_P4_2__HR______20240131T133230_20240131T142843_20240222T133401_3373_118_251_125_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (5/254) S6A_P4_2__HR______20240131T123618_20240131T133230_20240222T130752_3372_118_250_125_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (6/254) S6A_P4_2__HR______20240131T114005_20240131T123618_20240222T124719_3373_118_249_124_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (7/254) S6A_P4_2__HR______20240131T104352_20240131T114005_20240222T123325_3373_118_248_124_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (8/254) S6A_P4_2__HR______20240131T094739_20240131T104352_20240222T122418_3373_118_247_123_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (9/254) S6A_P4_2__HR______20240131T085126_20240131T094739_20240222T115831_3373_118_246_123_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (10/254) S6A_P4_2__HR______20240131T075513_20240131T085126_20240222T113834_3373_118_245_122_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (11/254) S6A_P4_2__HR______20240131T065900_20240131T075513_20240222T112645_3373_118_244_122_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (12/254) S6A_P4_2__HR______20240131T060247_20240131T065900_20240222T111424_3373_118_243_121_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (13/254) S6A_P4_2__HR______20240131T050634_20240131T060247_20240222T104834_3373_118_242_121_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (14/254) S6A_P4_2__HR______20240131T041022_20240131T050634_20240222T102931_3372_118_241_120_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (15/254) S6A_P4_2__HR______20240131T031409_20240131T041022_20240222T101740_3373_118_240_120_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (16/254) S6A_P4_2__HR______20240131T021756_20240131T031409_20240222T100429_3373_118_239_119_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (17/254) S6A_P4_2__HR______20240131T012143_20240131T021756_20240222T093828_3373_118_238_119_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (18/254) S6A_P4_2__HR______20240131T002530_20240131T012143_20240222T092043_3373_118_237_118_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (19/254) S6A_P4_2__HR______20240130T232917_20240131T002530_20240222T091045_3373_118_236_118_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (20/254) S6A_P4_2__HR______20240130T223304_20240130T232917_20240222T085516_3373_118_235_117_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (21/254) S6A_P4_2__HR______20240130T213651_20240130T223304_20240222T083020_3373_118_234_117_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (22/254) S6A_P4_2__HR______20240130T204039_20240130T213651_20240222T081447_3372_118_233_116_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (23/254) S6A_P4_2__HR______20240130T194426_20240130T204039_20240222T080154_3373_118_232_116_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (24/254) S6A_P4_2__HR______20240130T184813_20240130T194426_20240222T074424_3373_118_231_115_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (25/254) S6A_P4_2__HR______20240130T175200_20240130T184813_20240222T072105_3373_118_230_115_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (26/254) S6A_P4_2__HR______20240130T165547_20240130T175200_20240222T070635_3373_118_229_114_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (27/254) S6A_P4_2__HR______20240130T155934_20240130T165547_20240222T065452_3373_118_228_114_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (28/254) S6A_P4_2__HR______20240130T150321_20240130T155934_20240222T063502_3373_118_227_113_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (29/254) S6A_P4_2__HR______20240130T140708_20240130T150321_20240222T061005_3373_118_226_113_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (30/254) S6A_P4_2__HR______20240130T131055_20240130T140708_20240222T060047_3373_118_225_112_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (31/254) S6A_P4_2__HR______20240130T121443_20240130T131055_20240222T055124_3372_118_224_112_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (32/254) S6A_P4_2__HR______20240130T111830_20240130T121443_20240222T052957_3373_118_223_111_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (33/254) S6A_P4_2__HR______20240130T102217_20240130T111830_20240222T050239_3373_118_222_111_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (34/254) S6A_P4_2__HR______20240130T092604_20240130T102217_20240222T045430_3373_118_221_110_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (35/254) S6A_P4_2__HR______20240130T082951_20240130T092604_20240222T044410_3373_118_220_110_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (36/254) S6A_P4_2__HR______20240130T073338_20240130T082951_20240222T042253_3373_118_219_109_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (37/254) S6A_P4_2__HR______20240130T063725_20240130T073338_20240222T035646_3373_118_218_109_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (38/254) S6A_P4_2__HR______20240130T054112_20240130T063725_20240222T034737_3373_118_217_108_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (39/254) S6A_P4_2__HR______20240130T044500_20240130T054112_20240222T033940_3372_118_216_108_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (40/254) S6A_P4_2__HR______20240130T034847_20240130T044500_20240222T031508_3373_118_215_107_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (41/254) S6A_P4_2__HR______20240130T025234_20240130T034847_20240222T024853_3373_118_214_107_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (42/254) S6A_P4_2__HR______20240130T015621_20240130T025234_20240222T024244_3373_118_213_106_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (43/254) S6A_P4_2__HR______20240130T010008_20240130T015621_20240222T023418_3373_118_212_106_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (44/254) S6A_P4_2__HR______20240130T000355_20240130T010008_20240222T020529_3373_118_211_105_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (45/254) S6A_P4_2__HR______20240129T230742_20240130T000355_20240222T014300_3373_118_210_105_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (46/254) S6A_P4_2__HR______20240129T221129_20240129T230742_20240222T013645_3373_118_209_104_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (47/254) S6A_P4_2__HR______20240129T211517_20240129T221129_20240222T012748_3372_118_208_104_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (48/254) S6A_P4_2__HR______20240129T201904_20240129T211517_20240222T010021_3373_118_207_103_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (49/254) S6A_P4_2__HR______20240129T192251_20240129T201904_20240222T003606_3373_118_206_103_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (50/254) S6A_P4_2__HR______20240129T182638_20240129T192251_20240222T002909_3373_118_205_102_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (51/254) S6A_P4_2__HR______20240129T173025_20240129T182638_20240222T002105_3373_118_204_102_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (52/254) S6A_P4_2__HR______20240129T163412_20240129T173025_20240221T235246_3373_118_203_101_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (53/254) S6A_P4_2__HR______20240129T153759_20240129T163412_20240221T232931_3373_118_202_101_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (54/254) S6A_P4_2__HR______20240129T144146_20240129T153759_20240221T232300_3373_118_201_100_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (55/254) S6A_P4_2__HR______20240129T134534_20240129T144146_20240221T231149_3372_118_200_100_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (56/254) S6A_P4_2__HR______20240129T124921_20240129T134534_20240221T224538_3373_118_199_099_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (57/254) S6A_P4_2__HR______20240129T115308_20240129T124921_20240221T222337_3373_118_198_099_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (58/254) S6A_P4_2__HR______20240129T105655_20240129T115308_20240221T222046_3373_118_197_098_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (59/254) S6A_P4_2__HR______20240129T100042_20240129T105655_20240221T220404_3373_118_196_098_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (60/254) S6A_P4_2__HR______20240129T090429_20240129T100042_20240221T213926_3373_118_195_097_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (61/254) S6A_P4_2__HR______20240129T080816_20240129T090429_20240221T212017_3373_118_194_097_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (62/254) S6A_P4_2__HR______20240129T071203_20240129T080816_20240221T211303_3373_118_193_096_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (63/254) S6A_P4_2__HR______20240129T061550_20240129T071203_20240221T205525_3373_118_192_096_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (64/254) S6A_P4_2__HR______20240129T051938_20240129T061550_20240221T203251_3372_118_191_095_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (65/254) S6A_P4_2__HR______20240129T042325_20240129T051938_20240221T201342_3373_118_190_095_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (66/254) S6A_P4_2__HR______20240129T032712_20240129T042325_20240221T200547_3373_118_189_094_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (67/254) S6A_P4_2__HR______20240129T023059_20240129T032712_20240221T194842_3373_118_188_094_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (68/254) S6A_P4_2__HR______20240129T013446_20240129T023059_20240221T192544_3373_118_187_093_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (69/254) S6A_P4_2__HR______20240129T003833_20240129T013446_20240221T191054_3373_118_186_093_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (70/254) S6A_P4_2__HR______20240128T234220_20240129T003833_20240221T185836_3373_118_185_092_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (71/254) S6A_P4_2__HR______20240128T224607_20240128T234220_20240221T184029_3373_118_184_092_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (72/254) S6A_P4_2__HR______20240128T214955_20240128T224607_20240221T182138_3372_118_183_091_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (73/254) S6A_P4_2__HR______20240128T205342_20240128T214955_20240221T180448_3373_118_182_091_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (74/254) S6A_P4_2__HR______20240128T195729_20240128T205342_20240221T175313_3373_118_181_090_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (75/254) S6A_P4_2__HR______20240128T190116_20240128T195729_20240221T173405_3373_118_180_090_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (76/254) S6A_P4_2__HR______20240128T180503_20240128T190116_20240221T171701_3373_118_179_089_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (77/254) S6A_P4_2__HR______20240128T170850_20240128T180503_20240221T165806_3373_118_178_089_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (78/254) S6A_P4_2__HR______20240128T161237_20240128T170850_20240221T164520_3373_118_177_088_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (79/254) S6A_P4_2__HR______20240128T151624_20240128T161237_20240221T162520_3373_118_176_088_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (80/254) S6A_P4_2__HR______20240128T142012_20240128T151624_20240221T160824_3372_118_175_087_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (81/254) S6A_P4_2__HR______20240128T132359_20240128T142012_20240221T155119_3373_118_174_087_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (82/254) S6A_P4_2__HR______20240128T122746_20240128T132359_20240221T153759_3373_118_173_086_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (83/254) S6A_P4_2__HR______20240128T113133_20240128T122746_20240221T151810_3373_118_172_086_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (84/254) S6A_P4_2__HR______20240128T103520_20240128T113133_20240221T145849_3373_118_171_085_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (85/254) S6A_P4_2__HR______20240128T093909_20240128T103520_20240221T144417_3371_118_170_085_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (86/254) S6A_P4_2__HR______20240128T084254_20240128T093907_20240221T142943_3373_118_169_084_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (87/254) S6A_P4_2__HR______20240128T074641_20240128T084254_20240221T141350_3373_118_168_084_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (88/254) S6A_P4_2__HR______20240128T065028_20240128T074641_20240221T134950_3373_118_167_083_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (89/254) S6A_P4_2__HR______20240128T055416_20240128T065028_20240221T133426_3372_118_166_083_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (90/254) S6A_P4_2__HR______20240128T045803_20240128T055416_20240221T131934_3373_118_165_082_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (91/254) S6A_P4_2__HR______20240128T040150_20240128T045803_20240221T130519_3373_118_164_082_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (92/254) S6A_P4_2__HR______20240128T030537_20240128T040150_20240221T124014_3373_118_163_081_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (93/254) S6A_P4_2__HR______20240128T020924_20240128T030537_20240221T122510_3373_118_162_081_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (94/254) S6A_P4_2__HR______20240128T011311_20240128T020924_20240221T121045_3373_118_161_080_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (95/254) S6A_P4_2__HR______20240128T001658_20240128T011311_20240221T115847_3373_118_160_080_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (96/254) S6A_P4_2__HR______20240127T232045_20240128T001658_20240221T113147_3373_118_159_079_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (97/254) S6A_P4_2__HR______20240127T222433_20240127T232045_20240221T111653_3372_118_158_079_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (98/254) S6A_P4_2__HR______20240127T212820_20240127T222433_20240221T110423_3373_118_157_078_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (99/254) S6A_P4_2__HR______20240127T203207_20240127T212820_20240221T105003_3373_118_156_078_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (100/254) S6A_P4_2__HR______20240127T193554_20240127T203207_20240221T102225_3373_118_155_077_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (101/254) S6A_P4_2__HR______20240127T183941_20240127T193554_20240221T100727_3373_118_154_077_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (102/254) S6A_P4_2__HR______20240127T174328_20240127T183941_20240221T095337_3373_118_153_076_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (103/254) S6A_P4_2__HR______20240127T164715_20240127T174328_20240221T094113_3373_118_152_076_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (104/254) S6A_P4_2__HR______20240127T155102_20240127T164715_20240221T091206_3373_118_151_075_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (105/254) S6A_P4_2__HR______20240127T145450_20240127T155102_20240221T085656_3372_118_150_075_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (106/254) S6A_P4_2__HR______20240127T135837_20240127T145450_20240221T084237_3373_118_149_074_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (107/254) S6A_P4_2__HR______20240127T130224_20240127T135837_20240221T083133_3373_118_148_074_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (108/254) S6A_P4_2__HR______20240127T120611_20240127T130224_20240221T080530_3373_118_147_073_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (109/254) S6A_P4_2__HR______20240127T110958_20240127T120611_20240221T074738_3373_118_146_073_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (110/254) S6A_P4_2__HR______20240127T101345_20240127T110958_20240221T073341_3373_118_145_072_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (111/254) S6A_P4_2__HR______20240127T091732_20240127T101345_20240221T072355_3373_118_144_072_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (112/254) S6A_P4_2__HR______20240127T082119_20240127T091732_20240221T065755_3373_118_143_071_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (113/254) S6A_P4_2__HR______20240127T072506_20240127T082119_20240221T064245_3373_118_142_071_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (114/254) S6A_P4_2__HR______20240127T062854_20240127T072506_20240221T062809_3372_118_141_070_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (115/254) S6A_P4_2__HR______20240127T053241_20240127T062854_20240221T062122_3373_118_140_070_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (116/254) S6A_P4_2__HR______20240127T043628_20240127T053241_20240221T055112_3373_118_139_069_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (117/254) S6A_P4_2__HR______20240127T034015_20240127T043628_20240221T053504_3373_118_138_069_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (118/254) S6A_P4_2__HR______20240127T024402_20240127T034015_20240221T052331_3373_118_137_068_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (119/254) S6A_P4_2__HR______20240127T014749_20240127T024402_20240221T051722_3373_118_136_068_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (120/254) S6A_P4_2__HR______20240127T005136_20240127T014749_20240221T044405_3373_118_135_067_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (121/254) S6A_P4_2__HR______20240126T235523_20240127T005136_20240221T042923_3373_118_134_067_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (122/254) S6A_P4_2__HR______20240126T225911_20240126T235523_20240221T041914_3372_118_133_066_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (123/254) S6A_P4_2__HR______20240126T220258_20240126T225911_20240221T041125_3373_118_132_066_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (124/254) S6A_P4_2__HR______20240126T210645_20240126T220258_20240221T033852_3373_118_131_065_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (125/254) S6A_P4_2__HR______20240126T201032_20240126T210645_20240221T032236_3373_118_130_065_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (126/254) S6A_P4_2__HR______20240126T191419_20240126T201032_20240221T031504_3373_118_129_064_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (127/254) S6A_P4_2__HR______20240126T181806_20240126T191419_20240221T030501_3373_118_128_064_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (128/254) S6A_P4_2__HR______20240126T172153_20240126T181806_20240221T023004_3373_118_127_063_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (129/254) S6A_P4_2__HR______20240126T162540_20240126T172153_20240221T021627_3373_118_126_063_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (130/254) S6A_P4_2__HR______20240126T152927_20240126T162540_20240221T020921_3373_118_125_062_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (131/254) S6A_P4_2__HR______20240126T143315_20240126T152927_20240221T015455_3372_118_124_062_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (132/254) S6A_P4_2__HR______20240126T133702_20240126T143315_20240221T012348_3373_118_123_061_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (133/254) S6A_P4_2__HR______20240126T124049_20240126T133702_20240221T011107_3373_118_122_061_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (134/254) S6A_P4_2__HR______20240126T114436_20240126T124049_20240221T010657_3373_118_121_060_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (135/254) S6A_P4_2__HR______20240126T104823_20240126T114436_20240221T004930_3373_118_120_060_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (136/254) S6A_P4_2__HR______20240126T095210_20240126T104823_20240221T001759_3373_118_119_059_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (137/254) S6A_P4_2__HR______20240126T085557_20240126T095210_20240221T000813_3373_118_118_059_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (138/254) S6A_P4_2__HR______20240126T075944_20240126T085557_20240221T000017_3373_118_117_058_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (139/254) S6A_P4_2__HR______20240126T070332_20240126T075944_20240220T234234_3372_118_116_058_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (140/254) S6A_P4_2__HR______20240126T060719_20240126T070332_20240220T231107_3373_118_115_057_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (141/254) S6A_P4_2__HR______20240126T051106_20240126T060719_20240220T230121_3373_118_114_057_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (142/254) S6A_P4_2__HR______20240126T041453_20240126T051106_20240220T225348_3373_118_113_056_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (143/254) S6A_P4_2__HR______20240126T031840_20240126T041453_20240220T223509_3373_118_112_056_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (144/254) S6A_P4_2__HR______20240126T022227_20240126T031840_20240220T220356_3373_118_111_055_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (145/254) S6A_P4_2__HR______20240126T012614_20240126T022227_20240220T215553_3373_118_110_055_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (146/254) S6A_P4_2__HR______20240126T003001_20240126T012614_20240220T214642_3373_118_109_054_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (147/254) S6A_P4_2__HR______20240125T233349_20240126T003001_20240220T212854_3372_118_108_054_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (148/254) S6A_P4_2__HR______20240125T223736_20240125T233349_20240220T205538_3373_118_107_053_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (149/254) S6A_P4_2__HR______20240125T214123_20240125T223736_20240220T205013_3373_118_106_053_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (150/254) S6A_P4_2__HR______20240125T204510_20240125T214123_20240220T204200_3373_118_105_052_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (151/254) S6A_P4_2__HR______20240125T194857_20240125T204510_20240220T202150_3373_118_104_052_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (152/254) S6A_P4_2__HR______20240125T185244_20240125T194857_20240220T194859_3373_118_103_051_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (153/254) S6A_P4_2__HR______20240125T175631_20240125T185244_20240220T194247_3373_118_102_051_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (154/254) S6A_P4_2__HR______20240125T170018_20240125T175631_20240220T193423_3373_118_101_050_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (155/254) S6A_P4_2__HR______20240125T160405_20240125T170018_20240220T191409_3373_118_100_050_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (156/254) S6A_P4_2__HR______20240125T150753_20240125T160405_20240220T184416_3372_118_099_049_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (157/254) S6A_P4_2__HR______20240125T141140_20240125T150753_20240220T183540_3373_118_098_049_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (158/254) S6A_P4_2__HR______20240125T131527_20240125T141140_20240220T182848_3373_118_097_048_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (159/254) S6A_P4_2__HR______20240125T121914_20240125T131527_20240220T180846_3373_118_096_048_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (160/254) S6A_P4_2__HR______20240125T112301_20240125T121914_20240220T173724_3373_118_095_047_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (161/254) S6A_P4_2__HR______20240125T102648_20240125T112301_20240220T172928_3373_118_094_047_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (162/254) S6A_P4_2__HR______20240125T093035_20240125T102648_20240220T172305_3373_118_093_046_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (163/254) S6A_P4_2__HR______20240125T083423_20240125T093035_20240220T170607_3372_118_092_046_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (164/254) S6A_P4_2__HR______20240125T073810_20240125T083423_20240220T162815_3373_118_091_045_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (165/254) S6A_P4_2__HR______20240125T064157_20240125T073810_20240220T162046_3373_118_090_045_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (166/254) S6A_P4_2__HR______20240125T054544_20240125T064157_20240220T161339_3373_118_089_044_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (167/254) S6A_P4_2__HR______20240125T044931_20240125T054544_20240220T155927_3373_118_088_044_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (168/254) S6A_P4_2__HR______20240125T035318_20240125T044931_20240220T152037_3373_118_087_043_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (169/254) S6A_P4_2__HR______20240125T025705_20240125T035318_20240220T151158_3373_118_086_043_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (170/254) S6A_P4_2__HR______20240125T020052_20240125T025705_20240220T150530_3373_118_085_042_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (171/254) S6A_P4_2__HR______20240125T010439_20240125T020052_20240220T145550_3373_118_084_042_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (172/254) S6A_P4_2__HR______20240125T000827_20240125T010439_20240220T141134_3372_118_083_041_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (173/254) S6A_P4_2__HR______20240124T231214_20240125T000827_20240220T140328_3373_118_082_041_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (174/254) S6A_P4_2__HR______20240124T221601_20240124T231214_20240220T135914_3373_118_081_040_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (175/254) S6A_P4_2__HR______20240124T211948_20240124T221601_20240220T134813_3373_118_080_040_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (176/254) S6A_P4_2__HR______20240124T202335_20240124T211948_20240220T130344_3373_118_079_039_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (177/254) S6A_P4_2__HR______20240124T192722_20240124T202335_20240220T125449_3373_118_078_039_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (178/254) S6A_P4_2__HR______20240124T183109_20240124T192722_20240220T124859_3373_118_077_038_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (179/254) S6A_P4_2__HR______20240124T173456_20240124T183109_20240220T124122_3373_118_076_038_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (180/254) S6A_P4_2__HR______20240124T163843_20240124T173456_20240220T115417_3373_118_075_037_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (181/254) S6A_P4_2__HR______20240124T154231_20240124T163843_20240220T114259_3372_118_074_037_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (182/254) S6A_P4_2__HR______20240124T144618_20240124T154231_20240220T113837_3373_118_073_036_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (183/254) S6A_P4_2__HR______20240124T135005_20240124T144618_20240220T113243_3373_118_072_036_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (184/254) S6A_P4_2__HR______20240124T125352_20240124T135005_20240220T104658_3373_118_071_035_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (185/254) S6A_P4_2__HR______20240124T115739_20240124T125352_20240220T103401_3373_118_070_035_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (186/254) S6A_P4_2__HR______20240124T110126_20240124T115739_20240220T102925_3373_118_069_034_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (187/254) S6A_P4_2__HR______20240124T100513_20240124T110126_20240220T102325_3373_118_068_034_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (188/254) S6A_P4_2__HR______20240124T090901_20240124T100513_20240220T093721_3372_118_067_033_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (189/254) S6A_P4_2__HR______20240124T081248_20240124T090901_20240220T092452_3373_118_066_033_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (190/254) S6A_P4_2__HR______20240124T071635_20240124T081248_20240220T091917_3373_118_065_032_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (191/254) S6A_P4_2__HR______20240124T062022_20240124T071635_20240220T091459_3373_118_064_032_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (192/254) S6A_P4_2__HR______20240124T052409_20240124T062022_20240220T082623_3373_118_063_031_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (193/254) S6A_P4_2__HR______20240124T042756_20240124T052409_20240220T081419_3373_118_062_031_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (194/254) S6A_P4_2__HR______20240124T033143_20240124T042756_20240220T081001_3373_118_061_030_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (195/254) S6A_P4_2__HR______20240124T023530_20240124T033143_20240220T080357_3373_118_060_030_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (196/254) S6A_P4_2__HR______20240124T013917_20240124T023530_20240220T071621_3373_118_059_029_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (197/254) S6A_P4_2__HR______20240124T004305_20240124T013917_20240220T070442_3372_118_058_029_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (198/254) S6A_P4_2__HR______20240123T234652_20240124T004305_20240220T070245_3373_118_057_028_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (199/254) S6A_P4_2__HR______20240123T225039_20240123T234652_20240220T065640_3373_118_056_028_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (200/254) S6A_P4_2__HR______20240123T215426_20240123T225039_20240220T061033_3373_118_055_027_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (201/254) S6A_P4_2__HR______20240123T205813_20240123T215426_20240220T055713_3373_118_054_027_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (202/254) S6A_P4_2__HR______20240123T200200_20240123T205813_20240220T055251_3373_118_053_026_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (203/254) S6A_P4_2__HR______20240123T190547_20240123T200200_20240220T054930_3373_118_052_026_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (204/254) S6A_P4_2__HR______20240123T180934_20240123T190547_20240220T050357_3373_118_051_025_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (205/254) S6A_P4_2__HR______20240123T171321_20240123T180934_20240220T045033_3373_118_050_025_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (206/254) S6A_P4_2__HR______20240123T161709_20240123T171321_20240220T044436_3372_118_049_024_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (207/254) S6A_P4_2__HR______20240123T152056_20240123T161709_20240220T044101_3373_118_048_024_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (208/254) S6A_P4_2__HR______20240123T142443_20240123T152056_20240220T035501_3373_118_047_023_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (209/254) S6A_P4_2__HR______20240123T132830_20240123T142443_20240220T034458_3373_118_046_023_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (210/254) S6A_P4_2__HR______20240123T123217_20240123T132830_20240220T033952_3373_118_045_022_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (211/254) S6A_P4_2__HR______20240123T113604_20240123T123217_20240220T033534_3373_118_044_022_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (212/254) S6A_P4_2__HR______20240123T103951_20240123T113604_20240220T024712_3373_118_043_021_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (213/254) S6A_P4_2__HR______20240123T094339_20240123T103951_20240220T023830_3372_118_042_021_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (214/254) S6A_P4_2__HR______20240123T084726_20240123T094339_20240220T023252_3373_118_041_020_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (215/254) S6A_P4_2__HR______20240123T075113_20240123T084726_20240220T023155_3373_118_040_020_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (216/254) S6A_P4_2__HR______20240123T065500_20240123T075113_20240220T013944_3373_118_039_019_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (217/254) S6A_P4_2__HR______20240123T055847_20240123T065500_20240220T013429_3373_118_038_019_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (218/254) S6A_P4_2__HR______20240123T050234_20240123T055847_20240220T012626_3373_118_037_018_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (219/254) S6A_P4_2__HR______20240123T040621_20240123T050234_20240220T012505_3373_118_036_018_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (220/254) S6A_P4_2__HR______20240123T031008_20240123T040621_20240220T003135_3373_118_035_017_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (221/254) S6A_P4_2__HR______20240123T021355_20240123T031008_20240220T002830_3373_118_034_017_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (222/254) S6A_P4_2__HR______20240123T011743_20240123T021355_20240220T001717_3372_118_033_016_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (223/254) S6A_P4_2__HR______20240123T002130_20240123T011743_20240220T001731_3373_118_032_016_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (224/254) S6A_P4_2__HR______20240122T232517_20240123T002130_20240219T232253_3373_118_031_015_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (225/254) S6A_P4_2__HR______20240122T222904_20240122T232517_20240219T232450_3373_118_030_015_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (226/254) S6A_P4_2__HR______20240122T213251_20240122T222904_20240219T231358_3373_118_029_014_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (227/254) S6A_P4_2__HR______20240122T203638_20240122T213251_20240219T231147_3373_118_028_014_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (228/254) S6A_P4_2__HR______20240122T194025_20240122T203638_20240219T221740_3373_118_027_013_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (229/254) S6A_P4_2__HR______20240122T184412_20240122T194025_20240219T221730_3373_118_026_013_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (230/254) S6A_P4_2__HR______20240122T174800_20240122T184412_20240219T220456_3372_118_025_012_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (231/254) S6A_P4_2__HR______20240122T165147_20240122T174800_20240219T220520_3373_118_024_012_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (232/254) S6A_P4_2__HR______20240122T155534_20240122T165147_20240219T211116_3373_118_023_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (233/254) S6A_P4_2__HR______20240122T145921_20240122T155534_20240219T205858_3373_118_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (234/254) S6A_P4_2__HR______20240122T140308_20240122T145921_20240219T210802_3373_118_021_010_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (235/254) S6A_P4_2__HR______20240122T130655_20240122T140308_20240219T205856_3373_118_020_010_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (236/254) S6A_P4_2__HR______20240122T121042_20240122T130655_20240219T200258_3373_118_019_009_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (237/254) S6A_P4_2__HR______20240122T111430_20240122T121042_20240219T200240_3372_118_018_009_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (238/254) S6A_P4_2__HR______20240122T101817_20240122T111430_20240219T200131_3373_118_017_008_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (239/254) S6A_P4_2__HR______20240122T092204_20240122T101817_20240219T195627_3373_118_016_008_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (240/254) S6A_P4_2__HR______20240122T082551_20240122T092204_20240219T185555_3373_118_015_007_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (241/254) S6A_P4_2__HR______20240122T072938_20240122T082551_20240219T185612_3373_118_014_007_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (242/254) S6A_P4_2__HR______20240122T063325_20240122T072938_20240219T185344_3373_118_013_006_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (243/254) S6A_P4_2__HR______20240122T053712_20240122T063325_20240219T185001_3373_118_012_006_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (244/254) S6A_P4_2__HR______20240122T044059_20240122T053712_20240219T174810_3373_118_011_005_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (245/254) S6A_P4_2__HR______20240122T034446_20240122T044059_20240219T174847_3373_118_010_005_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (246/254) S6A_P4_2__HR______20240122T024834_20240122T034446_20240219T174650_3372_118_009_004_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (247/254) S6A_P4_2__HR______20240122T015221_20240122T024834_20240219T174603_3373_118_008_004_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (248/254) S6A_P4_2__HR______20240122T005608_20240122T015221_20240211T221602_3373_118_007_003_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (249/254) S6A_P4_2__HR______20240121T235955_20240122T005608_20240211T220911_3373_118_006_003_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (250/254) S6A_P4_2__HR______20240121T230342_20240121T235955_20240211T102618_3373_118_005_002_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (251/254) S6A_P4_2__HR______20240121T220729_20240121T230342_20240211T101939_3373_118_004_002_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (252/254) S6A_P4_2__HR______20240121T211116_20240121T220729_20240211T101320_3373_118_003_001_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (253/254) S6A_P4_2__HR______20240121T201503_20240121T211116_20240211T100652_3373_118_002_001_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (254/254) S6A_P4_2__HR______20240121T191850_20240121T201503_20240211T100024_3373_118_001_127_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section5'></a>5. Plotting a single cycle
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# Now we have downloaded the products, lets plot them to see how the coverage looks. We can collect all the manifest files using the cell below. This will read in each XML and parse it for the latitude/longitude coordinates of the track and store them in a list called `polygons`.

# %%
polygons = []
for downloaded_component in downloaded_components:
    tree = ET.parse(downloaded_component)
    root = tree.getroot()
    polygon =  root.findall('.//gml:posList', {'gml':'http://www.opengis.net/gml'})
    polygons.append((polygon[0].text))

# %% [markdown]
# We can now iterate through the `polygons` list and plot each track in turn until we have the full cycle coverage, as so.

# %%
fig, m = plt.subplots(1, 1, figsize=(20, 20), dpi=300, subplot_kw={"projection": cartopy.crs.PlateCarree()})

for polygon in polygons:
    coords = np.asarray(polygon.split(' ')).astype('float')
    halfway = round(len(coords) / 4) * 2
    p, = m.plot(coords[1:halfway:2], coords[0:halfway:2], color='b', 
                linewidth=1, transform=cartopy.crs.Geodetic(), zorder=1)

# add some map embellishments
m.add_feature(cartopy.feature.NaturalEarthFeature('physical', 'land', '50m', edgecolor='k', facecolor='#546d51', linewidth=0.5), zorder=8)
m.set_global()

g1 = m.gridlines(draw_labels = True, linestyle='--', zorder=10)
g1.top_labels = g1.right_labels = False
g1.xlabel_style = g1.ylabel_style = {'color': 'gray'}
plt.title(f'Sentinel-6; cycle {S6_cycle}')
plt.show()

# %% [markdown]
# There we have it, a full cycle of tracks from Sentinel-6! We can see from the track mesh that, due to the orbital inclination angle of Sentinel-6 (66$^{o}$), we only sample the ocean between 66$^{o}$S and 66$^{o}$N, but have dense coverage over the 10-day cycle in between. Sentinel-6B will compliment this, and is currenrly due for launch in 2026.
#
# If we wanted to, we could replicate the process above using the `eumdac` command line interface (CLI) as follows, and making the relevant substitutions.

# %% [markdown]
# `eumdac search -c <collectionID> --cycle <cycle_number> --timeliness <timeliness> >> products_cycle_number.txt`
#
# `eumdac download -c <collectionID> -p @products_cycle_number.txt`

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section6'></a>6. Searching for our specified products by relative orbit
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# Lets now repeat the process, but prune by relative orbit. This is simple for Sentinel-3, as can be done like so;

# %%
S3_products = S3_collection.search(relorbit=S3_relorbit, orbitdir=S3_orbitdir, timeliness=timeliness)
print(len(S3_products))
# Out:
# 29

# %% [markdown]
# For Sentinel-6 it is a bit more complicated as we need to manualy determine the orbit direction from the relative pass number in the filename (see the top of this notebook for more information).
#
# *Note: In the future this information will be encoded in the EUMETSAT Data Store.*

# %%
S6_products = S6_collection.search(relorbit=S6_relorbit, timeliness=timeliness)

# get the descending passes (even numbered relative passes)
S6_products_prune = []
for product in S6_products:
    rel_pass = int(str(product).split('_')[15])
    if S6_orbitdir == "ASCENDING" and (rel_pass % 2) == 1:
        S6_products_prune.append(product)
    elif S6_orbitdir == "DESCENDING" and (rel_pass % 2) == 0:
        S6_products_prune.append(product)

S6_products = S6_products_prune
print(len(S6_products))
# Out:
# 41

# %% [markdown]
# Lets download exactly we did in the previous experiment, but store the output in out `download_rel_orbit` directory;

# %%
if download_data:
    downloaded_components = []
    
    for product, count in zip(S6_products, range(len(S6_products))):
    
        product_download_directory = os.path.join(download_dir_relorbit, str(product))
        os.makedirs(product_download_directory, exist_ok=True)
    
        # download the required product components
        for entry in product.entries:
            res = [ele for ele in components if(ele == os.path.basename(entry))]
            if res:
                with product.open(entry=entry) as fsrc, open(os.path.join(product_download_directory, fsrc.name),
                                                            mode='wb') as fdst:
                    downloaded_components.append(os.path.join(product_download_directory, fsrc.name))
                    print(f'Downloading ({count+1}/{len(S6_products)}) {product}: {fsrc.name}.')
                    shutil.copyfileobj(fsrc, fdst)
else:
    downloaded_components = sorted(glob.glob(os.path.join(download_dir_relorbit, "*", components[0])))
# Out:
# Downloading (1/41) S6A_P4_2__HR______20240312T045158_20240312T054811_20240507T155724_3373_123_022_011_EUM__OPE_NT_F09.SEN6: xfdumanifest.xml.
# Downloading (2/41) S6A_P4_2__HR______20240302T065326_20240302T074939_20240424T165626_3373_122_022_011_EUM__OPE_NT_F09.SEN6: xfdumanifest.xml.
# Downloading (3/41) S6A_P4_2__HR______20240221T085455_20240221T095108_20240320T015240_3373_121_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (4/41) S6A_P4_2__HR______20240211T105624_20240211T115237_20240308T135422_3373_120_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (5/41) S6A_P4_2__HR______20240201T125752_20240201T135405_20240229T000624_3373_119_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (6/41) S6A_P4_2__HR______20240122T145921_20240122T155534_20240219T205858_3373_118_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (7/41) S6A_P4_2__HR______20240112T170049_20240112T175702_20240208T041920_3373_117_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (8/41) S6A_P4_2__HR______20240102T190218_20240102T195831_20240129T193040_3373_116_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (9/41) S6A_P4_2__HR______20231223T210346_20231223T215959_20240113T101433_3373_115_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (10/41) S6A_P4_2__HR______20231213T230514_20231213T235547_20240103T220624_3033_114_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (11/41) S6A_P4_2__HR______20231204T010641_20231204T020254_20231229T144941_3373_113_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (12/41) S6A_P4_2__HR______20231124T030810_20231124T040423_20231220T204548_3373_112_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (13/41) S6A_P4_2__HR______20231114T050939_20231114T060552_20231211T184644_3373_111_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (14/41) S6A_P4_2__HR______20231104T071108_20231104T080721_20231201T035532_3373_110_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (15/41) S6A_P4_2__HR______20231025T091237_20231025T100850_20231122T045741_3373_109_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (16/41) S6A_P4_2__HR______20231015T111406_20231015T121019_20231110T080511_3373_108_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (17/41) S6A_P4_2__HR______20231005T131534_20231005T141147_20231106T193733_3373_107_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (18/41) S6A_P4_2__HR______20230925T151702_20230925T161315_20231023T135448_3373_106_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (19/41) S6A_P4_2__HR______20230915T171831_20230915T181443_20231012T233027_3372_105_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (20/41) S6A_P4_2__HR______20230905T191959_20230905T201612_20231002T233942_3373_104_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (21/41) S6A_P4_2__HR______20230826T212127_20230826T221740_20230918T065545_3373_103_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (22/41) S6A_P4_2__HR______20230816T232255_20230817T001907_20230908T012538_3372_102_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (23/41) S6A_P4_2__HR______20230807T012422_20230807T020748_20230904T114213_2606_101_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (24/41) S6A_P4_2__HR______20230728T032551_20230728T042204_20230823T115925_3373_100_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (25/41) S6A_P4_2__HR______20230718T052720_20230718T062332_20230814T132430_3372_099_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (26/41) S6A_P4_2__HR______20230708T072848_20230708T082501_20230803T192312_3373_098_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (27/41) S6A_P4_2__HR______20230628T093017_20230628T102630_20230726T173803_3373_097_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (28/41) S6A_P4_2__HR______20230618T113145_20230618T122758_20230715T234337_3373_096_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (29/41) S6A_P4_2__HR______20230608T133313_20230608T141531_20230704T155517_2538_095_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (30/41) S6A_P4_2__HR______20230529T153441_20230529T163054_20230626T191900_3373_094_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (31/41) S6A_P4_2__HR______20230519T173610_20230519T183222_20230616T195542_3372_093_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (32/41) S6A_P4_2__HR______20230509T193739_20230509T203352_20230605T205314_3373_092_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (33/41) S6A_P4_2__HR______20230429T213908_20230429T223013_20230520T155219_3065_091_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (34/41) S6A_P4_2__HR______20230419T234037_20230420T003650_20230510T220816_3373_090_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (35/41) S6A_P4_2__HR______20230410T014206_20230410T023818_20230507T025612_3372_089_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (36/41) S6A_P4_2__HR______20230331T034334_20230331T043947_20230427T175759_3373_088_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (37/41) S6A_P4_2__HR______20230321T054503_20230321T064115_20230417T011653_3372_087_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (38/41) S6A_P4_2__HR______20230311T074631_20230311T084244_20230406T162327_3373_086_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (39/41) S6A_P4_2__HR______20230301T094759_20230301T104412_20230331T113456_3373_085_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (40/41) S6A_P4_2__HR______20230219T114927_20230219T124540_20230318T024431_3373_084_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.
# Downloading (41/41) S6A_P4_2__HR______20230209T135055_20230209T144708_20230309T181530_3373_083_022_011_EUM__OPE_NT_F08.SEN6: xfdumanifest.xml.

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section7'></a>7. Plotting a relative orbit
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# ...and finally, lets plot the data. As before, we can collect then track coverage data from the manifest files and store these in a list (called `polygons`).

# %%
polygons = []
for downloaded_component in downloaded_components:
    tree = ET.parse(downloaded_component)
    root = tree.getroot()
    polygon =  root.findall('.//gml:posList', {'gml':'http://www.opengis.net/gml'})
    polygons.append((polygon[0].text))

# %% [markdown]
# Finally, lets iterate through these polygons and plot them in turn.

# %%
fig, m = plt.subplots(1, 1, figsize=(20, 20), dpi=300, subplot_kw={"projection": cartopy.crs.PlateCarree()})

for polygon, count in zip(polygons, range(len(polygons))):
    coords = np.asarray(polygon.split(' ')).astype('float')
    halfway = round(len(coords) / 4 - 1) * 2
    p, = m.plot(coords[1:halfway:2], coords[0:halfway:2], c=plt.cm.viridis(count/len(polygons)), 
                transform=cartopy.crs.Geodetic(), zorder=10, linewidth=(len(polygons)-count)/2)

# add some map embellishments
m.add_feature(cartopy.feature.NaturalEarthFeature('physical', 'land', '50m', edgecolor='k', facecolor='#546d51', linewidth=0.5), zorder=8)
m.set_global()
g1 = m.gridlines(draw_labels = True, linestyle='--', zorder=10)
g1.top_labels = g1.right_labels = False
g1.xlabel_style = g1.ylabel_style = {'color': 'gray'}
plt.title(f'Sentinel-6; relative orbit {S6_relorbit} ({S6_orbitdir})')
plt.show()

# %% [markdown]
# Each track above is plotted in a different colour and thickness, with older, thicker tracks in purple, and newer, thinner tracks in yellow. You can see that, line-thickness aside, all the tracks overlay each other and have the same coverage, meaning that we can use this approach to build timeseries over each point.
#
# If we wanted to, we could replicate the process above using the `eumdac` command line interface (CLI) as follows, and making the relevant substitutions.

# %% [markdown]
# `eumdac search -c <collectionID> --relorbit <relative_orbit_number> --timeliness <timeliness> >> products_relorbit.txt`
#
# `eumdac download -c <collectionID> -p @products_relorbit.txt`

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section8'></a>8. Conclusions
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# In this notebook we have shown how to prune altimetry searches and downloads by orbital parameter. For altimetry applications, this approach is usually more useful than using time and/or region of interest based searching. You can apply the above approaches to select any Sentinel-3 or Sentinel-6 altimetry data, adapting the cycles and rleative orbits to your own requirements.

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
# ## <a id='section9'></a>9. Challenge (Optional)
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# When you have run the script with the default settings, why not try to;
# * combine the searches above to isolate a single pass in a single cycle, or
# * adapt the components to download the actual data for a given satellite and plot the sea surface height anomaly data across a single cycle

# %% [markdown]
# <hr>
# <a href="../../../Index.ipynb"><< Index</a>
# <hr>
# <a href="https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/applications/ocean-case-studies">View on GitLab</a> | <a href="https://training.eumetsat.int/">EUMETSAT Training</a> | <a href=mailto:ops@eumetsat.int>Contact helpdesk for support </a> | <a href=mailto:.training@eumetsat.int>Contact our training team to collaborate on and reuse this material</a></span></p>
